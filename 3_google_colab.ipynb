# %% [markdown]
# <a href="https://colab.research.google.com/github/Vladislav2367/Data_Science_Bibl/blob/main/3_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Что такое jupyter ноутбук

# %%
print('well done')
# Out:
# well done

# %% [markdown]
# Здесь есть ячейки с кодом, которые можем выполнять, так же здесь есть ячейки с текстом, что очень удобно для фиксирования своих идей и результатов эксперимента.

# %% [markdown]
# ## Создание ноутбука

# %% [markdown]
# "Файл" -> "Создать ноутбук"

# %% [markdown]
# ## Где ноутбук?
#
# "Файл" -> "Показать местоположение на Диске"

# %% [markdown]
# ## Как поделиться ноутбуком?
#
# "Поделиться"
#
# - Выбрать с кем
# - Или выбрать по ссылке
# - Указать права доступа

# %% [markdown]
# ## Чужой ноутбук
#
# https://colab.research.google.com/#scrollTo=2fhs6GZ4qFMx
#
# "Файл" -> "Создать копию на Диске"

# %% [markdown]
# ## Выполнение кода
#
# - ctrl + enter
# - shift + enter
# - alt + enter

# %%
a = 5
a + 4
# Out:
# 9

# %% [markdown]
# ## Создание новых ячеек
#
# - A
# - B

# %% [markdown]
# ## Перевод ячеек
#
# - ctrl + m + m
# - ctrl + m + y

# %% [markdown]
# ## Удаление ячеек
# - ctrl + m + d

# %% [markdown]
# ## Работа с файлами

# %% [markdown]
# 1. Закинуть в левую область

# %% [markdown]
# 2. Через модель files

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ce86f2e5-d75c-44ae-9eb3-2811c506fc0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce86f2e5-d75c-44ae-9eb3-2811c506fc0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screenshot_20220318_150332.png to Screenshot_20220318_150332.png
# ...

# %% [markdown]
# 3. Подключение google drive

# %% [markdown]
# ## Практика
# Практика доступна на платформе boosty:
# https://boosty.to/machine_learrrning/posts/fd5bd121-c05a-455d-b3b0-b47700425416
#
# Доступна
# 1. по подписке уровня light+ и выше
# 2. разовая оплата
